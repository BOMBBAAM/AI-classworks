# %% [markdown]
# <a href="https://colab.research.google.com/github/BOMBBAAM/AI-classworks/blob/main/6330034821_MultiLayer_Perceptron_tf2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 1.1 : Multilayer Perceptron (MLP)**

# %%
# %tensorflow_version
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ## **Step 1: Import library**

# %%
import numpy as np
from numpy.random import seed
seed(42)
import tensorflow as tf


from tensorflow.keras.layers import Dense,Input, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import Model
import matplotlib.pyplot as plt

# %%
nb_epochs = 35
batch_size = 32
nb_classes = 10
class_name = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck',
}

# %%
cifar = tf.keras.datasets.cifar10

# %% [markdown]
# ## **Step 2: Load data (CIFAR10)**

# %%
(x_train,y_train),(x_test,y_test) = cifar.load_data()
y_train, y_test = y_train.reshape(y_train.shape[0]), y_test.reshape(y_test.shape[0])
x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000,)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# ## **Step 3: Visualize example data**

# %%
def draw_img(i):
    im = x_train[i]
    c = y_train[i]
    plt.imshow(im)
    plt.title("Class %d (%s)" % (c, class_name[c]))
    plt.axis('on')

def draw_sample(X, y, n, rows=4, cols=4, imfile=None, fontsize=12):
    for i in range(0, rows*cols):
        plt.subplot(rows, cols, i+1)
        im = X[n+i].reshape(32,32,3)
        plt.imshow(im, cmap=plt.cm.binary)
        plt.title("{}".format(class_name[y[n+i]]), fontsize=fontsize)
        plt.axis('off')
        plt.subplots_adjust(wspace=0.6, hspace=0.01)

# %%
draw_img(7)

# %%
draw_sample(x_train, y_train, 0, 3, 5)

# %% [markdown]
# ## **Step 4: Create Multilayer Perceptron Model**
#
# > Dense layers are keras alias for Fully connected layers. These layers give the ability to classify the features learned by the CNN.

# %% [markdown]
# Overfit

# %%
input = Input(shape = (32,32,3))
x = Flatten()(input)
x = Dense(32, activation='relu')(x)
prediction = Dense(10, activation='softmax')(x)
model = Model(inputs = input, outputs = prediction)

# %% [markdown]
# ## **Step 5: Loss,  Optimizer, Early stopping**

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=2, min_lr=1e-6)
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## **Step 6: Fit model**

# %%
h = model.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 12s 4ms/step - loss: 2.1506 - accuracy: 0.1670 - val_loss: 2.0817 - val_accuracy: 0.1839 - lr: 0.0010
# Epoch 2/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0719 - accuracy: 0.1850 - val_loss: 2.0526 - val_accuracy: 0.1874 - lr: 0.0010
# Epoch 3/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.0533 - accuracy: 0.1882 - val_loss: 2.0780 - val_accuracy: 0.1844 - lr: 0.0010
# Epoch 4/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0457 - accuracy: 0.1881 - val_loss: 2.0397 - val_accuracy: 0.1983 - lr: 0.0010
# Epoch 5/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0417 - accuracy: 0.1916 - val_loss: 2.0410 - val_accuracy: 0.1886 - lr: 0.0010
# Epoch 6/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0405 - accuracy: 0.1906 - val_loss: 2.0309 - val_accuracy: 0.1877 - lr: 0.0010
# Epoch 7/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0372 - accuracy: 0.1907 - val_loss: 2.0358 - val_accuracy: 0.1984 - lr: 0.0010
# Epoch 8/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0361 - accuracy: 0.1898 - val_loss: 2.0812 - val_accuracy: 0.1765 - lr: 0.0010
# Epoch 9/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0369 - accuracy: 0.1893 - val_loss: 2.0364 - val_accuracy: 0.1910 - lr: 0.0010
# Epoch 10/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0347 - accuracy: 0.1900 - val_loss: 2.0312 - val_accuracy: 0.1851 - lr: 0.0010
# Epoch 11/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0353 - accuracy: 0.1876 - val_loss: 2.0541 - val_accuracy: 0.1882 - lr: 0.0010
# Epoch 12/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0340 - accuracy: 0.1903 - val_loss: 2.0359 - val_accuracy: 0.1888 - lr: 0.0010
# Epoch 13/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0329 - accuracy: 0.1913 - val_loss: 2.0295 - val_accuracy: 0.1903 - lr: 0.0010
# Epoch 14/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0337 - accuracy: 0.1899 - val_loss: 2.0315 - val_accuracy: 0.1909 - lr: 0.0010
# Epoch 15/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0325 - accuracy: 0.1890 - val_loss: 2.0342 - val_accuracy: 0.1873 - lr: 0.0010
# Epoch 16/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0309 - accuracy: 0.1911 - val_loss: 2.0265 - val_accuracy: 0.1876 - lr: 0.0010
# Epoch 17/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0315 - accuracy: 0.1905 - val_loss: 2.0318 - val_accuracy: 0.1803 - lr: 0.0010
# Epoch 18/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0319 - accuracy: 0.1892 - val_loss: 2.0267 - val_accuracy: 0.1899 - lr: 0.0010
# Epoch 19/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0240 - accuracy: 0.1935 - val_loss: 2.0260 - val_accuracy: 0.1867 - lr: 2.0000e-04
# Epoch 20/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0234 - accuracy: 0.1947 - val_loss: 2.0258 - val_accuracy: 0.1911 - lr: 2.0000e-04
# Epoch 21/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0239 - accuracy: 0.1949 - val_loss: 2.0303 - val_accuracy: 0.1888 - lr: 2.0000e-04
# Epoch 22/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0236 - accuracy: 0.1913 - val_loss: 2.0252 - val_accuracy: 0.1912 - lr: 2.0000e-04
# Epoch 23/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0217 - accuracy: 0.1972 - val_loss: 2.0250 - val_accuracy: 0.1912 - lr: 4.0000e-05
# Epoch 24/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0215 - accuracy: 0.1919 - val_loss: 2.0253 - val_accuracy: 0.1901 - lr: 4.0000e-05
# Epoch 25/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0217 - accuracy: 0.1918 - val_loss: 2.0252 - val_accuracy: 0.1904 - lr: 4.0000e-05
# Epoch 26/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0215 - accuracy: 0.1936 - val_loss: 2.0253 - val_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 27/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0212 - accuracy: 0.1924 - val_loss: 2.0250 - val_accuracy: 0.1913 - lr: 8.0000e-06
# Epoch 28/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0212 - accuracy: 0.1913 - val_loss: 2.0249 - val_accuracy: 0.1929 - lr: 8.0000e-06
# Epoch 29/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0211 - accuracy: 0.1915 - val_loss: 2.0249 - val_accuracy: 0.1924 - lr: 8.0000e-06
# Epoch 30/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0211 - accuracy: 0.1910 - val_loss: 2.0249 - val_accuracy: 0.1915 - lr: 1.6000e-06
# Epoch 31/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0211 - accuracy: 0.1912 - val_loss: 2.0249 - val_accuracy: 0.1911 - lr: 1.6000e-06
# Epoch 32/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0210 - accuracy: 0.1914 - val_loss: 2.0249 - val_accuracy: 0.1909 - lr: 1.6000e-06
# Epoch 33/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0210 - accuracy: 0.1912 - val_loss: 2.0249 - val_accuracy: 0.1912 - lr: 1.0000e-06
# Epoch 34/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.0210 - accuracy: 0.1912 - val_loss: 2.0249 - val_accuracy: 0.1911 - lr: 1.0000e-06
# Epoch 35/35
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0210 - accuracy: 0.1912 - val_loss: 2.0249 - val_accuracy: 0.1911 - lr: 1.0000e-06

# %% [markdown]
# ## **Step 7: Plot loss and accuracy**

# %%
history_dict = h.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo')
plt.plot(epochs, val_loss_values, 'b+')
plt.title('Model loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc_values, 'bo')
plt.plot(epochs, val_acc_values, 'b+')
plt.title('Model accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
lr_values = history_dict['lr']

plt.plot(epochs, lr_values, 'bo')
plt.title('Learning rate')
plt.xlabel('Epochs')
plt.ylabel('Learning rate')

plt.show()

# %% [markdown]
# ## **Step 8: Evaluate**

# %%
loss, accuracy = model.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.191260  ;  loss = 2.021018

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Validation: accuracy = 0.191100  ;  loss = 2.024925

# %% [markdown]
# ## **Step 9 : Confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # **Lab 1.2 : Add Dropout**

# %% [markdown]
# ## **Step 10 : Add Dropout**
#
# > Dropout is the method used to reduce overfitting. It forces the model to learn multiple independent representations of the same data by randomly disabling neurons in the learning phase. In our model, dropout will randomnly disable 20% of the neurons.

# %%
input = Input(shape = (32,32,3))
x = Flatten()(input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(256, activation = 'relu')(x)
prediction = Dense(10, activation='softmax')(x)
model_2 = Model(inputs = input, outputs = prediction)

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=2, min_lr=1e-6)
model_2.compile(optimizer='Adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
h_2 = model_2.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.9679 - accuracy: 0.2756 - val_loss: 1.8110 - val_accuracy: 0.3374 - lr: 0.0010
# Epoch 2/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.8438 - accuracy: 0.3283 - val_loss: 1.7420 - val_accuracy: 0.3715 - lr: 0.0010
# Epoch 3/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7912 - accuracy: 0.3461 - val_loss: 1.7145 - val_accuracy: 0.3887 - lr: 0.0010
# Epoch 4/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7638 - accuracy: 0.3584 - val_loss: 1.6893 - val_accuracy: 0.3976 - lr: 0.0010
# Epoch 5/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7441 - accuracy: 0.3678 - val_loss: 1.6563 - val_accuracy: 0.4043 - lr: 0.0010
# Epoch 6/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7161 - accuracy: 0.3797 - val_loss: 1.6951 - val_accuracy: 0.3948 - lr: 0.0010
# Epoch 7/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7056 - accuracy: 0.3816 - val_loss: 1.6437 - val_accuracy: 0.4125 - lr: 0.0010
# Epoch 8/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6945 - accuracy: 0.3889 - val_loss: 1.6452 - val_accuracy: 0.4050 - lr: 0.0010
# Epoch 9/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6772 - accuracy: 0.3939 - val_loss: 1.6062 - val_accuracy: 0.4276 - lr: 0.0010
# Epoch 10/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6697 - accuracy: 0.3955 - val_loss: 1.6129 - val_accuracy: 0.4257 - lr: 0.0010
# Epoch 11/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6657 - accuracy: 0.3985 - val_loss: 1.6096 - val_accuracy: 0.4298 - lr: 0.0010
# Epoch 12/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6559 - accuracy: 0.4004 - val_loss: 1.5952 - val_accuracy: 0.4274 - lr: 0.0010
# Epoch 13/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6488 - accuracy: 0.4064 - val_loss: 1.5802 - val_accuracy: 0.4411 - lr: 0.0010
# Epoch 14/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6430 - accuracy: 0.4094 - val_loss: 1.5752 - val_accuracy: 0.4393 - lr: 0.0010
# Epoch 15/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6380 - accuracy: 0.4089 - val_loss: 1.5867 - val_accuracy: 0.4338 - lr: 0.0010
# Epoch 16/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6346 - accuracy: 0.4118 - val_loss: 1.5992 - val_accuracy: 0.4265 - lr: 0.0010
# Epoch 17/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6270 - accuracy: 0.4172 - val_loss: 1.5827 - val_accuracy: 0.4411 - lr: 0.0010
# Epoch 18/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6297 - accuracy: 0.4135 - val_loss: 1.5774 - val_accuracy: 0.4327 - lr: 0.0010
# Epoch 19/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6149 - accuracy: 0.4195 - val_loss: 1.5993 - val_accuracy: 0.4245 - lr: 0.0010
# Epoch 20/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6138 - accuracy: 0.4171 - val_loss: 1.5983 - val_accuracy: 0.4313 - lr: 0.0010
# Epoch 21/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6109 - accuracy: 0.4187 - val_loss: 1.5737 - val_accuracy: 0.4428 - lr: 0.0010
# Epoch 22/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6066 - accuracy: 0.4218 - val_loss: 1.6217 - val_accuracy: 0.4252 - lr: 0.0010
# Epoch 23/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6005 - accuracy: 0.4231 - val_loss: 1.5786 - val_accuracy: 0.4401 - lr: 0.0010
# Epoch 24/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5965 - accuracy: 0.4270 - val_loss: 1.5914 - val_accuracy: 0.4336 - lr: 0.0010
# Epoch 25/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5933 - accuracy: 0.4281 - val_loss: 1.5504 - val_accuracy: 0.4477 - lr: 0.0010
# Epoch 26/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5914 - accuracy: 0.4291 - val_loss: 1.5478 - val_accuracy: 0.4481 - lr: 0.0010
# Epoch 27/35
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5913 - accuracy: 0.4256 - val_loss: 1.5421 - val_accuracy: 0.4573 - lr: 0.0010
# Epoch 28/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5825 - accuracy: 0.4315 - val_loss: 1.5919 - val_accuracy: 0.4350 - lr: 0.0010
# Epoch 29/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5784 - accuracy: 0.4310 - val_loss: 1.5303 - val_accuracy: 0.4581 - lr: 0.0010
# Epoch 30/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5757 - accuracy: 0.4336 - val_loss: 1.5757 - val_accuracy: 0.4330 - lr: 0.0010
# Epoch 31/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5695 - accuracy: 0.4368 - val_loss: 1.5346 - val_accuracy: 0.4554 - lr: 0.0010
# Epoch 32/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5700 - accuracy: 0.4354 - val_loss: 1.5224 - val_accuracy: 0.4590 - lr: 0.0010
# Epoch 33/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5744 - accuracy: 0.4335 - val_loss: 1.5394 - val_accuracy: 0.4578 - lr: 0.0010
# Epoch 34/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5084 - accuracy: 0.4610 - val_loss: 1.5106 - val_accuracy: 0.4637 - lr: 2.0000e-04
# Epoch 35/35
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4909 - accuracy: 0.4634 - val_loss: 1.5005 - val_accuracy: 0.4652 - lr: 2.0000e-04

# %%
model_2.save_weights('myModel_adam.h5')

# %%
history_dict_2 = h_2.history
history_dict_2.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
loss_values = history_dict_2['loss']
val_loss_values = history_dict_2['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo')
plt.plot(epochs, val_loss_values, 'b+')
plt.title('Model loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc_values = history_dict_2['accuracy']
val_acc_values = history_dict_2['val_accuracy']

plt.plot(epochs, acc_values, 'bo')
plt.plot(epochs, val_acc_values, 'b+')
plt.title('Model accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
loss, accuracy = model_2.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.500980  ;  loss = 1.413336

# %%
loss, accuracy = model_2.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Validation: accuracy = 0.465200  ;  loss = 1.500512

# %%
# Predict the values from the validation dataset
Y_pred = model_2.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # **Step 11: Inspecting output**

# %%
predicted = model_2.predict(x_test)
predicted_classes = np.argmax(predicted,axis=1)
correct_indices = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != y_test)[0]
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
print("Number of true predictions: ", len(correct_indices))
print("Number of false predictions:", len(incorrect_indices))
# Out:
# Number of true predictions:  4652
# Number of false predictions: 5348

# %%
plt.rcParams['figure.figsize'] = (9,9) 
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[correct], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(class_name[predicted_classes[correct]], class_name[y_test[correct]]))
    plt.subplots_adjust(wspace=1.2, hspace=0.01)

# %%
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[incorrect], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(class_name[predicted_classes[incorrect]], class_name[y_test[incorrect]]))
    plt.subplots_adjust(wspace=0.6, hspace=0.01)

# %% [markdown]
# # **Exercise**

# %% [markdown]
# ## Mnist Data
#
# ```
# The MNIST database contains 60,000 training images and 10,000 testing images taken from American Census Bureau employees and American high school students [4]. Therefore, in the second line, I have separated these two groups as train and test and also separated the labels and the images. x_train and x_test parts contain greyscale RGB codes (from 0 to 255) while y_train and y_test parts contains labels from 0 to 9 which represents which number they actually are.
# ![Example Mnist dataset](https://drive.google.com/open?id=1EjLwrpjtoCgo6kgdVgaMVc-ATxKnGmtn)
# ```

# %%
nb_epochs = 300
batch_size = 32
nb_classes = 10

# %% [markdown]
# ## Import Mnist Dataset

# %%
# To do
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()
y_train, y_test = y_train.reshape(y_train.shape[0]), y_test.reshape(y_test.shape[0])
x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
y_train, y_test = y_train.reshape(y_train.shape[0]), y_test.reshape(y_test.shape[0])
x_train = x_train.astype('float32') 
x_test = x_test.astype('float32')
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## Create Model MLP

# %%
# To Do
input = Input(shape = (28,28))
x = Flatten()(input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
prediction = Dense(10, activation='softmax')(x)
model_3 = Model(inputs = input, outputs = prediction)

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
input = Input(shape = (28,28))
x = Flatten()(input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
prediction = Dense(10, activation='softmax')(x)
model_3 = Model(inputs = input, outputs = prediction)

# %% [markdown]
# ## Add Early stopping, Reduce learning rate and compile

# %%
# To Do
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=10, min_lr=1e-3)
model_3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=10, min_lr=0.001)
model_3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Fit model

# %%
# To Do
h_3 = model_3.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2212 - accuracy: 0.9338 - val_loss: 0.1119 - val_accuracy: 0.9634 - lr: 0.0010
# Epoch 2/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0981 - accuracy: 0.9704 - val_loss: 0.0825 - val_accuracy: 0.9737 - lr: 0.0010
# Epoch 3/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0707 - accuracy: 0.9772 - val_loss: 0.0748 - val_accuracy: 0.9766 - lr: 0.0010
# Epoch 4/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0553 - accuracy: 0.9821 - val_loss: 0.0712 - val_accuracy: 0.9785 - lr: 0.0010
# Epoch 5/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0434 - accuracy: 0.9861 - val_loss: 0.0640 - val_accuracy: 0.9802 - lr: 0.0010
# Epoch 6/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 0.0715 - val_accuracy: 0.9793 - lr: 0.0010
# Epoch 7/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0303 - accuracy: 0.9896 - val_loss: 0.0704 - val_accuracy: 0.9812 - lr: 0.0010
# Epoch 8/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.0675 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 9/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0243 - accuracy: 0.9917 - val_loss: 0.0759 - val_accuracy: 0.9816 - lr: 0.0010
# Epoch 10/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 0.0682 - val_accuracy: 0.9830 - lr: 0.0010
# Epoch 11/300
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0196 - accuracy: 0.9931 - val_loss: 0.0902 - val_accuracy: 0.9787 - lr: 0.0010
# Epoch 12/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.0732 - val_accuracy: 0.9830 - lr: 0.0010
# Epoch 13/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0703 - val_accuracy: 0.9842 - lr: 0.0010
# Epoch 14/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0167 - accuracy: 0.9944 - val_loss: 0.0878 - val_accuracy: 0.9808 - lr: 0.0010
# Epoch 15/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0814 - val_accuracy: 0.9827 - lr: 0.0010
# Epoch 15: early stopping

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
h_3 = model_3.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/300
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2208 - accuracy: 0.9345 - val_loss: 0.1036 - val_accuracy: 0.9676 - lr: 0.0010
# Epoch 2/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0952 - accuracy: 0.9706 - val_loss: 0.0946 - val_accuracy: 0.9705 - lr: 0.0010
# Epoch 3/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0690 - accuracy: 0.9782 - val_loss: 0.0745 - val_accuracy: 0.9767 - lr: 0.0010
# Epoch 4/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0523 - accuracy: 0.9834 - val_loss: 0.0660 - val_accuracy: 0.9796 - lr: 0.0010
# Epoch 5/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0435 - accuracy: 0.9856 - val_loss: 0.0655 - val_accuracy: 0.9803 - lr: 0.0010
# Epoch 6/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0344 - accuracy: 0.9886 - val_loss: 0.0672 - val_accuracy: 0.9818 - lr: 0.0010
# Epoch 7/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0304 - accuracy: 0.9899 - val_loss: 0.0684 - val_accuracy: 0.9814 - lr: 0.0010
# Epoch 8/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0277 - accuracy: 0.9909 - val_loss: 0.0770 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 9/300
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0248 - accuracy: 0.9917 - val_loss: 0.0782 - val_accuracy: 0.9806 - lr: 0.0010
# Epoch 10/300
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0221 - accuracy: 0.9923 - val_loss: 0.0648 - val_accuracy: 0.9836 - lr: 0.0010
# Epoch 11/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0190 - accuracy: 0.9936 - val_loss: 0.0781 - val_accuracy: 0.9802 - lr: 0.0010
# Epoch 12/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.0790 - val_accuracy: 0.9822 - lr: 0.0010
# Epoch 13/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.0780 - val_accuracy: 0.9823 - lr: 0.0010
# Epoch 14/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.0727 - val_accuracy: 0.9839 - lr: 0.0010
# Epoch 15/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.0762 - val_accuracy: 0.9835 - lr: 0.0010
# Epoch 16/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0149 - accuracy: 0.9945 - val_loss: 0.0770 - val_accuracy: 0.9836 - lr: 0.0010
# Epoch 17/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0917 - val_accuracy: 0.9817 - lr: 0.0010
# Epoch 18/300
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.0794 - val_accuracy: 0.9840 - lr: 0.0010
# Epoch 19/300
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0841 - val_accuracy: 0.9842 - lr: 0.0010
# Epoch 20/300
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0907 - val_accuracy: 0.9832 - lr: 0.0010
# Epoch 20: early stopping

# %% [markdown]
# ## Plot accuracy and loss

# %%
history_dict_3 = h_3.history
history_dict_3.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
loss_values = history_dict_3['loss']
val_loss_values = history_dict_3['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo')
plt.plot(epochs, val_loss_values, 'b+')
plt.title('Model loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc_values = history_dict_3['accuracy']
val_acc_values = history_dict_3['val_accuracy']

plt.plot(epochs, acc_values, 'bo')
plt.plot(epochs, val_acc_values, 'b+')
plt.title('Model accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %% [markdown]
# ## Evaluate

# %%
# To Do
loss, accuracy = model_3.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
loss, accuracy = model_3.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.998283  ;  loss = 0.004869
# Validation: accuracy = 0.982700  ;  loss = 0.081414

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
loss, accuracy = model_3.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.998867  ;  loss = 0.003322

# %%
loss, accuracy = model_3.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Validation: accuracy = 0.983200  ;  loss = 0.090698

# %% [markdown]
# ## Confusion Matrix

# %%
# Predict the values from the validation dataset
Y_pred = model_3.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred, axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## Inspecting output

# %%
predicted = model_3.predict(x_test)
predicted_classes = np.argmax(predicted,axis=1)
correct_indices_2 = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices_2 = np.nonzero(predicted_classes != y_test)[0]
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
print("Number of true predictions: ", len(correct_indices_2))
print("Number of false predictions:", len(incorrect_indices_2))
# Out:
# Number of true predictions:  9827
# Number of false predictions: 173

# %%
plt.rcParams['figure.figsize'] = (9,9) 
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[correct], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
    plt.subplots_adjust(wspace=1.2, hspace=0.01)

# %%
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[incorrect], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
    plt.subplots_adjust(wspace=0.6, hspace=0.01)
